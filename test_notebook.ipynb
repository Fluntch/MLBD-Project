# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
activity = pd.read_csv('data/original/activity.csv')

# %%
activity
# Out:
#        Unnamed: 0  activity_id  user_id  post_id  course_id activity_type  \
# 0              75         1111     2533     1696       1696        access
# 1              76         1112     2533     1696       1696        course
# 2              77         1113     2533     1699       1696        lesson
# 3              78         1114     2533     1769       1696         topic
# 4              79         1115     2533     1711       1696         topic
# ...           ...          ...      ...      ...        ...           ...
# 72892         627          627     2516  2000627       2115          exam
# 72893         628          628     1629  2000628       5009          exam
# 72894         629          629     2185  2000629       2115          exam
# 72895         630          630     2516  2000630       5009          exam
# 72896         631          631     1859  2000631       5009          exam
#
#        activity_status  activity_started  activity_completed  activity_updated
# ...

# %%
activity.activity_type.value_counts()
# Out:
# activity_type
# topic             44714
# lesson            15436
# quiz               6799
# exam               2619
# course             2507
# access              774
# group_progress       48
# Name: count, dtype: int64

# %%
activity
