# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
user_days = pd.read_csv('data/features/user_days.csv')
activity = pd.read_csv('data/features/activity.csv')
performances = pd.read_csv('data/features/performances.csv')

# %%
activity[activity['activity_type']=='exam'] # this is weird --> exam as activity and most of those have time spent = 0
# Out:
#        activity_id  user_id  post_id  course_id activity_type  \
# 50145            0     1286  1000000       5447          exam
# 50146            1     1107  1000001       3301          exam
# 50147            2     1286  1000002       5447          exam
# 50148            3     1091  1000003       5447          exam
# 50149            4     1091  1000004       5447          exam
# ...            ...      ...      ...        ...           ...
# 52739          627     2516  2000627       2115          exam
# 52740          628     1629  2000628       5009          exam
# 52741          629     2185  2000629       2115          exam
# 52742          630     2516  2000630       5009          exam
# 52743          631     1859  2000631       5009          exam
#
#        activity_status     activity_started   activity_completed  \
# 50145                1  2024-07-12 10:21:47                  NaN
# 50146                1  2024-07-12 14:53:34                  NaN
# 50147                1  2024-08-02 16:12:49                  NaN
# 50148                1  2024-08-05 11:17:34                  NaN
# 50149                1  2024-08-07 07:53:34                  NaN
# ...                ...                  ...                  ...
# 52739                1  2025-01-04 13:42:05  2025-01-04 13:42:05
# 52740                1  2024-08-26 17:44:36  2024-08-26 18:25:07
# 52741                1  2024-10-30 14:02:31  2024-10-30 14:02:34
# 52742                1  2025-01-04 13:08:50  2025-01-04 13:11:53
# 52743                1  2025-01-05 17:52:30  2025-01-05 18:26:35
#
#           activity_updated domain  date_restored  times_valid        date  \
# 50145  2024-07-12 10:21:47  essay          False         True  2024-07-12
# 50146  2024-07-12 14:53:34  essay          False         True  2024-07-12
# 50147  2024-08-02 16:12:49  essay          False         True  2024-08-02
# 50148  2024-08-05 11:17:34  essay          False         True  2024-08-05
# 50149  2024-08-07 07:53:34  essay          False         True  2024-08-07
# ...                    ...    ...            ...          ...         ...
# 52739  2025-01-04 13:42:05   text          False         True  2025-01-04
# 52740  2024-08-26 18:25:07   text          False         True  2024-08-26
# 52741  2024-10-30 14:02:34   text          False         True  2024-10-30
# 52742  2025-01-04 13:11:53   text          False         True  2025-01-04
# 52743  2025-01-05 18:26:35   text          False         True  2025-01-05
#
#             time_spent  time_in_minutes  time_truncated
# 50145  0 days 00:00:00         0.000000           False
# 50146  0 days 00:00:00         0.000000           False
# 50147  0 days 00:00:00         0.000000           False
# 50148  0 days 00:00:00         0.000000           False
# 50149  0 days 00:00:00         0.000000           False
# ...                ...              ...             ...
# 52739  0 days 00:00:00         0.000000           False
# 52740  0 days 00:40:31        40.516667           False
# 52741  0 days 00:00:03         0.050000           False
# 52742  0 days 00:03:03         3.050000           False
# 52743  0 days 00:34:05        34.083333           False
#
# [2599 rows x 16 columns]

# %%
activity[activity['activity_type']=='exam'].time_in_minutes.value_counts()
# Out:
# time_in_minutes
# 0.000000     2225
# 75.000000      49
# 0.083333        7
# 0.133333        4
# 0.100000        3
#              ...
# 11.566667       1
# 65.633333       1
# 48.083333       1
# 48.500000       1
# 34.083333       1
# Name: count, Length: 295, dtype: int64

# %%
activity.activity_type.value_counts()
# Out:
# activity_type
# topic     30850
# lesson    11348
# quiz       6742
# exam       2599
# course      717
# access      488
# Name: count, dtype: int64

# %% [markdown]
# ## First lets try to predict math exam results

# %%
user_days_math = user_days[user_days['domain']== 'math'].copy()
performances_math = performances[performances['domain']== 'math'].copy()
activity_math = activity[activity['domain']== 'math'].copy()

# %%
user_days_math
# Out:
#        user_id        date      type  user_day  number_of_activities domain  \
# 21           1  2025-02-13  activity        19                     2   math
# 22           1  2025-02-15  activity        20                     1   math
# 23           1  2025-02-16  activity        21                     2   math
# 24           1  2025-02-16  activity        21                     2   math
# 25           1  2025-02-17  activity        22                     3   math
# ...        ...         ...       ...       ...                   ...    ...
# 19821     4095  2024-10-30      both        14                     8   math
# 19822     4095  2024-11-13  activity        15                     5   math
# 19825     4095  2024-12-02  activity        17                     3   math
# 19826     4095  2024-12-03      both        18                     9   math
# 19827     4095  2024-12-03      both        18                     9   math
#
#       activity_type  time_in_minutes
# 21            topic        16.116667
# 22            topic        30.000000
# 23           lesson         0.000000
# 24            topic         0.483333
# 25           lesson         0.000000
# ...             ...              ...
# 19821         topic       156.466667
# 19822         topic        87.000000
# 19825         topic        55.933333
# 19826          quiz        27.333333
# 19827         topic         0.000000
#
# [8843 rows x 8 columns]

# %%
activity_math
# Out:
#        activity_id  user_id  post_id  course_id activity_type  \
# 0             1128     2533       42         42        course
# 1             1129     2533       55         42        lesson
# 2             1130     2533       98         42         topic
# 3             1131     2533      100         42         topic
# 4             1132     2533      102         42         topic
# ...            ...      ...      ...        ...           ...
# 50137       114742      955      647         42         topic
# 50138       114743      955      106         42         topic
# 50139       114744      955      104         42         topic
# 50140       114745      955      108         42         topic
# 50141       114746      955     2945         42          quiz
#
#        activity_status     activity_started   activity_completed  \
# 0                    0  2023-04-07 16:42:35  2023-04-07 17:35:15
# 1                    0  2023-04-07 16:42:35                  NaN
# 2                    1  2023-04-07 16:42:38  2023-04-07 16:43:58
# 3                    1  2023-04-07 16:43:59  2023-04-07 16:46:13
# 4                    1  2023-04-07 16:46:14  2023-04-07 16:46:27
# ...                ...                  ...                  ...
# 50137                0  2025-03-07 06:36:32                  NaN
# 50138                0  2025-03-07 06:37:49                  NaN
# 50139                0  2025-03-07 06:37:50                  NaN
# 50140                0  2025-03-07 06:37:54                  NaN
# 50141                1  2025-03-07 06:42:09  2025-03-07 06:54:21
#
#           activity_updated domain  date_restored  times_valid        date  \
# 0      2023-04-07 17:35:15   math           True         True  2023-04-07
# 1      2023-04-07 16:42:35   math          False         True  2023-04-07
# 2      2023-04-07 16:43:58   math          False         True  2023-04-07
# 3      2023-04-07 16:46:13   math          False         True  2023-04-07
# 4      2023-04-07 16:46:27   math          False         True  2023-04-07
# ...                    ...    ...            ...          ...         ...
# 50137  2025-03-07 06:36:32   math          False         True  2025-03-07
# 50138  2025-03-07 06:37:49   math          False         True  2025-03-07
# 50139  2025-03-07 06:37:50   math          False         True  2025-03-07
# 50140  2025-03-07 06:37:54   math          False         True  2025-03-07
# 50141  2025-03-07 06:54:21   math          False         True  2025-03-07
#
#             time_spent  time_in_minutes  time_truncated
# 0      0 days 00:52:40        52.666667           False
# 1      0 days 00:00:00         0.000000           False
# 2      0 days 00:01:20         1.333333           False
# 3      0 days 00:02:14         2.233333           False
# 4      0 days 00:00:13         0.216667           False
# ...                ...              ...             ...
# 50137  0 days 00:00:00         0.000000           False
# 50138  0 days 00:00:00         0.000000           False
# 50139  0 days 00:00:00         0.000000           False
# 50140  0 days 00:00:00         0.000000           False
# 50141  0 days 00:12:12        12.200000           False
#
# [25938 rows x 16 columns]

# %%
activity_math.isnull().sum()
# Out:
# activity_id               0
# user_id                   0
# post_id                   0
# course_id                 0
# activity_type             0
# activity_status           0
# activity_started          0
# activity_completed    12676
# activity_updated          0
# domain                    0
# date_restored             0
# times_valid               0
# date                      0
# time_spent                0
# time_in_minutes           0
# time_truncated            0
# dtype: int64

# %%
performances_math
# Out:
#       user_id domain test_id  course        date  percentage  performance
# 9           6   math      42    3865  2024-11-23       25.00       -36.04
# 10          6   math      48    3865  2025-01-08       50.00        -1.92
# 11          6   math      49    3865  2025-01-08       66.67        21.23
# 12          6   math      50    3865  2025-02-04       54.55        19.57
# 13          6   math      54    3865  2024-11-23       14.29       -47.71
# ...       ...    ...     ...     ...         ...         ...          ...
# 4826     4095   math      49    3865  2024-10-18        0.00       -45.44
# 4827     4095   math      50    3865  2024-10-18        0.00       -34.98
# 4828     4095   math      51    3865  2024-09-24       20.00       -22.98
# 4829     4095   math      53    3865  2024-09-24        0.00       -56.46
# 4830     4095   math      54    3865  2024-10-30       28.57       -33.43
#
# [3810 rows x 7 columns]

# %%
activity_math.dropna(inplace=True) # not sure what to do here, drops almost 50% of the rows but would those rows would fuck up the time spent on activity feature as it was 0 for all of them

# %%
activity_math.activity_type.value_counts()
# Out:
# activity_type
# topic     6699
# quiz      6278
# lesson     143
# access      74
# course      68
# Name: count, dtype: int64

# %% [markdown]
# ## Feature extraction

# %%
# Rolling window for recent activity
rolling_window_days = 10

# Convert the 'date' columns to datetime
activity_math['date'] = pd.to_datetime(activity_math['date'])
performances_math['date'] = pd.to_datetime(performances_math['date'])

def compute_all_features_for_exam(exam_row, user_activities, user_exams, window_days=rolling_window_days):

    exam_date = exam_row['date']

    # Include activities up to and including exam_date
    previous_activities = user_activities[user_activities['date'] <= exam_date].copy() # need to modify to have the exact date and time in the performance df, because here activities that happend after the exam on the same day will be accounted for.

    # Rolling window (activities in the last N days, including exam day)
    window_start = exam_date - pd.Timedelta(days=window_days)
    rolling_activities = previous_activities[previous_activities['date'] >= window_start].copy()

    features = {}

    # Recent average time per activity (rolling window)
    total_time_rolling = rolling_activities['time_in_minutes'].sum()
    count_rolling = len(rolling_activities)
    features['recent_avg_time_per_activity'] = total_time_rolling / count_rolling if count_rolling > 0 else np.nan

    # Number of days since last activity
    if not previous_activities.empty:
        last_activity_date = previous_activities['date'].max()
        features['days_since_last_activity'] = (exam_date - last_activity_date).days
    else:
        features['days_since_last_activity'] = np.nan

    # Total time spent on activities before the exam
    features['total_time_spent_on_activity_before_exam'] = previous_activities['time_in_minutes'].sum() if not previous_activities.empty else np.nan

    # Average percentage on past exams
    previous_exams = user_exams[user_exams['date'] < exam_date]
    features['average_percentage_past_exams'] = previous_exams['percentage'].mean() if not previous_exams.empty else np.nan

    # Usage Frequency: Average activities per day in rolling window & Active days ratio
    features['avg_activities_per_day_recent'] = count_rolling / window_days if window_days > 0 else np.nan
    if not rolling_activities.empty:
        distinct_days = rolling_activities['date'].dt.normalize().nunique()
    else:
        distinct_days = 0
    features['active_days_ratio_recent'] = distinct_days / window_days if window_days > 0 else np.nan

    # Activity diversity (rolling window)
    features['diversity_recent'] = rolling_activities['activity_type'].nunique() if not rolling_activities.empty else np.nan


    return pd.Series(features)

# Loop over each exam (grouped by user) in performances_math and compute all features.
features_list = []

for user_id, user_exams in performances_math.groupby('user_id'):
    # Get corresponding activities for the user from activity_math and sort by date
    user_activities = activity_math[activity_math['user_id'] == user_id].sort_values('date')
    user_exams_sorted = user_exams.sort_values('date')

    for exam_index, exam_row in user_exams_sorted.iterrows():
        feats = compute_all_features_for_exam(exam_row, user_activities, user_exams_sorted, rolling_window_days)
        feats['exam_index'] = exam_index
        features_list.append(feats)

# Output df
features_df = pd.DataFrame(features_list).set_index('exam_index')
performances_math_features = performances_math.join(features_df, how='left')

# %%
performances_math_features
# Out:
#         user_id domain test_id  course       date  percentage  performance  \
# 9.0           6   math      42    3865 2024-11-23       25.00       -36.04
# 10.0          6   math      48    3865 2025-01-08       50.00        -1.92
# 11.0          6   math      49    3865 2025-01-08       66.67        21.23
# 12.0          6   math      50    3865 2025-02-04       54.55        19.57
# 13.0          6   math      54    3865 2024-11-23       14.29       -47.71
# ...         ...    ...     ...     ...        ...         ...          ...
# 4826.0     4095   math      49    3865 2024-10-18        0.00       -45.44
# 4827.0     4095   math      50    3865 2024-10-18        0.00       -34.98
# 4828.0     4095   math      51    3865 2024-09-24       20.00       -22.98
# 4829.0     4095   math      53    3865 2024-09-24        0.00       -56.46
# 4830.0     4095   math      54    3865 2024-10-30       28.57       -33.43
#
#         recent_avg_time_per_activity  days_since_last_activity  \
# 9.0                        22.701282                       0.0
# 10.0                       28.891667                       0.0
# 11.0                       28.891667                       0.0
# 12.0                       89.533333                       0.0
# 13.0                       22.701282                       0.0
# ...                              ...                       ...
# 4826.0                     91.672222                       0.0
# 4827.0                     91.672222                       0.0
# 4828.0                     15.388095                       0.0
# 4829.0                     15.388095                       0.0
# 4830.0                     38.987500                       0.0
#
#         total_time_spent_on_activity_before_exam  \
# 9.0                                   299.533333
# 10.0                                  472.883333
# 11.0                                  472.883333
# 12.0                                  597.816667
# 13.0                                  299.533333
# ...                                          ...
# 4826.0                                489.600000
# 4827.0                                489.600000
# 4828.0                                197.716667
# 4829.0                                197.716667
# 4830.0                                801.500000
#
#         average_percentage_past_exams  avg_activities_per_day_recent  \
# 9.0                               NaN                            1.3
# 10.0                        29.822500                            0.6
# 11.0                        29.822500                            0.6
# 12.0                        39.326667                            0.1
# 13.0                              NaN                            1.3
# ...                               ...                            ...
# 4826.0                      10.833333                            0.3
# 4827.0                      10.833333                            0.3
# 4828.0                            NaN                            0.7
# 4829.0                            NaN                            0.7
# 4830.0                      13.750000                            0.8
#
#         active_days_ratio_recent  diversity_recent
# 9.0                          0.2               2.0
# 10.0                         0.2               2.0
# 11.0                         0.2               2.0
# 12.0                         0.1               1.0
# 13.0                         0.2               2.0
# ...                          ...               ...
# 4826.0                       0.1               1.0
# 4827.0                       0.1               1.0
# 4828.0                       0.2               2.0
# 4829.0                       0.2               2.0
# 4830.0                       0.1               2.0
#
# [3810 rows x 14 columns]

# %% [markdown]
#  Here not sure how we should handle the average percentage on last exams when it's the first exam a student takes do we take the average ?

# %%
from sklearn.preprocessing import StandardScaler


# scaling the columns
columns_to_scale = ['recent_avg_time_per_activity', 'days_since_last_activity', 'total_time_spent_on_activity_before_exam','average_percentage_past_exams','avg_activities_per_day_recent','diversity_recent']


scaler = StandardScaler()
scaled_values = scaler.fit_transform(performances_math_features[columns_to_scale])
scaled_df = pd.DataFrame(scaled_values, columns=columns_to_scale, index=performances_math_features.index)
remaining_df = performances_math_features.drop(columns=columns_to_scale)
final_df = pd.concat([scaled_df, remaining_df], axis=1)

# %%
final_df.isnull().sum()
# Out:
# recent_avg_time_per_activity                  8
# days_since_last_activity                      2
# total_time_spent_on_activity_before_exam      2
# average_percentage_past_exams               777
# avg_activities_per_day_recent                 0
# diversity_recent                              8
# user_id                                       0
# domain                                        0
# test_id                                       0
# course                                        0
# date                                          0
# percentage                                    0
# performance                                   0
# active_days_ratio_recent                      0
# dtype: int64

# %%
final_df.dropna(inplace=True)

# %%
import statsmodels.formula.api as smf

# Linear Regression Model
mod = smf.ols(formula='performance ~  recent_avg_time_per_activity + days_since_last_activity + total_time_spent_on_activity_before_exam + average_percentage_past_exams + avg_activities_per_day_recent + diversity_recent', data=final_df)

# Fit the model
res = mod.fit()

# Print regression results summary
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            performance   R-squared:                       0.240
# Model:                            OLS   Adj. R-squared:                  0.238
# Method:                 Least Squares   F-statistic:                     158.7
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):          1.20e-175
# Time:                        09:44:27   Log-Likelihood:                -14026.
# No. Observations:                3028   AIC:                         2.807e+04
# Df Residuals:                    3021   BIC:                         2.811e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    0.9298      0.478      1.945      0.052      -0.007       1.867
# recent_avg_time_per_activity                 5.5106      0.528     10.445      0.000       4.476       6.545
# days_since_last_activity                     4.7166      4.263      1.106      0.269      -3.642      13.076
# total_time_spent_on_activity_before_exam     2.6456      0.475      5.571      0.000       1.714       3.577
# average_percentage_past_exams                9.2169      0.482     19.131      0.000       8.272      10.162
# avg_activities_per_day_recent               -2.9693      0.483     -6.152      0.000      -3.916      -2.023
# diversity_recent                             0.4781      0.545      0.877      0.380      -0.590       1.546
# ==============================================================================
# Omnibus:                       41.761   Durbin-Watson:                   1.502
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.494
# Skew:                          -0.095   Prob(JB):                     1.07e-06
# Kurtosis:                       2.573   Cond. No.                         12.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Let's try with the essay results

# %%
performances_essay = performances[performances['domain']== 'essay'].copy()
activity_essay= activity[activity['domain']== 'essay'].copy()

# %%
activity_essay.isnull().sum() # big issue with the activity completed comlumn, way too many nans.
# Out:
# activity_id              0
# user_id                  0
# post_id                  0
# course_id                0
# activity_type            0
# activity_status          0
# activity_started         0
# activity_completed    9550
# activity_updated         0
# domain                   0
# date_restored            0
# times_valid              0
# date                     0
# time_spent               0
# time_in_minutes          0
# time_truncated           0
# dtype: int64

# %%
activity_essay.dropna(inplace=True)

# %%
activity_essay
# Out:
#        activity_id  user_id  post_id  course_id activity_type  \
# 241          23817     2560     3301       3301        access
# 258          24116     2574     5447       5447        access
# 263          24131     2574     5466       5447         topic
# 264          24132     2574     5467       5447         topic
# 265          24133     2574     5469       5447         topic
# ...            ...      ...      ...        ...           ...
# 49818       114296      944    15622       5447          quiz
# 50006       114564      959    15595       5447         topic
# 50056       114616      922    15727       5447         topic
# 50116       114704      955     5447       5447        course
# 50121       114726      955    15606       5447         topic
#
#        activity_status     activity_started   activity_completed  \
# 241                  0  2023-11-26 08:58:42  2023-11-26 08:58:49
# 258                  0  2023-11-27 13:33:10  2023-11-27 13:33:18
# 263                  1  2023-11-27 13:52:33  2023-11-27 15:54:13
# 264                  1  2023-11-27 13:52:37  2023-11-27 15:53:51
# 265                  1  2023-11-27 13:52:39  2023-11-27 15:50:05
# ...                ...                  ...                  ...
# 49818                1  2025-03-03 12:17:09  2025-03-03 12:21:15
# 50006                1  2025-03-05 16:31:00  2025-03-05 16:31:06
# 50056                1  2025-03-05 18:20:23  2025-03-05 18:20:43
# 50116                0  2025-03-06 18:00:55  2025-03-06 18:27:06
# 50121                1  2025-03-06 18:21:49  2025-03-06 18:27:06
#
#           activity_updated domain  date_restored  times_valid        date  \
# 241    2023-11-26 08:58:49  essay           True         True  2023-11-26
# 258    2023-11-27 13:33:18  essay           True         True  2023-11-27
# 263    2023-11-27 15:54:13  essay          False         True  2023-11-27
# 264    2023-11-27 15:53:51  essay          False         True  2023-11-27
# 265    2023-11-27 15:50:05  essay          False         True  2023-11-27
# ...                    ...    ...            ...          ...         ...
# 49818  2025-03-03 12:21:15  essay          False         True  2025-03-03
# 50006  2025-03-05 16:31:06  essay          False         True  2025-03-05
# 50056  2025-03-05 18:20:43  essay          False         True  2025-03-05
# 50116  2025-03-06 18:27:06  essay           True         True  2025-03-06
# 50121  2025-03-06 18:27:06  essay          False         True  2025-03-06
#
#             time_spent  time_in_minutes  time_truncated
# 241    0 days 00:00:07         0.116667           False
# 258    0 days 00:00:08         0.133333           False
# 263    0 days 00:30:00        30.000000            True
# 264    0 days 00:30:00        30.000000            True
# 265    0 days 00:30:00        30.000000            True
# ...                ...              ...             ...
# 49818  0 days 00:04:06         4.100000           False
# 50006  0 days 00:00:06         0.100000           False
# 50056  0 days 00:00:20         0.333333           False
# 50116  0 days 00:26:11        26.183333           False
# 50121  0 days 00:05:17         5.283333           False
#
# [4146 rows x 16 columns]

# %%
performances_essay.isnull().sum()
# Out:
# user_id        0
# domain         0
# test_id        0
# course         0
# date           0
# percentage     0
# performance    0
# dtype: int64

# %%
# Convert the date columns  to datetime
activity_essay['date'] = pd.to_datetime(activity_essay['date'])
performances_essay['date'] = pd.to_datetime(performances_essay['date'])

# Loop over each exam (grouped by user) in performances_essay and compute all features.
features_list = []

for user_id, user_exams in performances_essay.groupby('user_id'):
    # Get corresponding activities for the user from activity_essay and sort by date
    user_activities = activity_essay[activity_essay['user_id'] == user_id].sort_values('date')
    user_exams_sorted = user_exams.sort_values('date')

    for exam_index, exam_row in user_exams_sorted.iterrows():
        feats = compute_all_features_for_exam(exam_row, user_activities, user_exams_sorted, rolling_window_days)
        feats['exam_index'] = exam_index
        features_list.append(feats)

# Output df
features_df = pd.DataFrame(features_list).set_index('exam_index')
performances_essay_features = performances_essay.join(features_df, how='left')

# %%
performances_essay_features
# Out:
#         user_id domain       test_id  course       date  percentage  \
# 0.0           1  essay   eroerterung    3301 2024-11-29   63.000000
# 1.0           1  essay    erzaehlung    5447 2024-10-26   55.294118
# 2.0           4  essay   eroerterung    3301 2024-11-21   66.000000
# 3.0           4  essay    erzaehlung    3301 2024-11-07   71.000000
# 4.0           5  essay    erzaehlung    5447 2024-10-26   44.705882
# ...         ...    ...           ...     ...        ...         ...
# 4781.0     4087  essay   eroerterung    3301 2024-12-17   64.000000
# 4782.0     4087  essay    erzaehlung    3301 2024-11-03   71.000000
# 4806.0     4089  essay    erzaehlung    5447 2024-11-03   50.588235
# 4807.0     4092  essay  beschreibung    3301 2024-12-24   69.000000
# 4818.0     4095  essay   eroerterung    3301 2024-12-09   58.000000
#
#         performance  recent_avg_time_per_activity  days_since_last_activity  \
# 0.0       -7.090000                           NaN                      27.0
# 1.0       -8.075882                           NaN                       NaN
# 2.0       -4.090000                     11.233333                      10.0
# 3.0        3.390000                           NaN                       NaN
# 4.0      -18.664118                           NaN                       NaN
# ...             ...                           ...                       ...
# 4781.0    -6.090000                           NaN                      97.0
# 4782.0     3.390000                           NaN                      53.0
# 4806.0   -12.781765                           NaN                      49.0
# 4807.0    -0.960000                     17.483333                       0.0
# 4818.0   -12.090000                           NaN                      48.0
#
#         total_time_spent_on_activity_before_exam  \
# 0.0                                     4.983333
# 1.0                                          NaN
# 2.0                                    22.466667
# 3.0                                          NaN
# 4.0                                          NaN
# ...                                          ...
# 4781.0                                 34.566667
# 4782.0                                 34.566667
# 4806.0                                112.650000
# 4807.0                                353.933333
# 4818.0                                 73.800000
#
#         average_percentage_past_exams  avg_activities_per_day_recent  \
# 0.0                         55.294118                            0.0
# 1.0                               NaN                            0.0
# 2.0                         71.000000                            0.2
# 3.0                               NaN                            0.0
# 4.0                               NaN                            0.0
# ...                               ...                            ...
# 4781.0                      71.000000                            0.0
# 4782.0                            NaN                            0.0
# 4806.0                            NaN                            0.0
# 4807.0                            NaN                            1.6
# 4818.0                            NaN                            0.0
#
#         active_days_ratio_recent  diversity_recent
# 0.0                          0.0               NaN
# 1.0                          0.0               NaN
# 2.0                          0.1               1.0
# 3.0                          0.0               NaN
# 4.0                          0.0               NaN
# ...                          ...               ...
# 4781.0                       0.0               NaN
# 4782.0                       0.0               NaN
# 4806.0                       0.0               NaN
# 4807.0                       0.1               3.0
# 4818.0                       0.0               NaN
#
# [581 rows x 14 columns]

# %%
performances_essay_features.isnull().sum() # too many nans in the features for essay.
# Out:
# user_id                                       0
# domain                                        0
# test_id                                       0
# course                                        0
# date                                          0
# percentage                                    0
# performance                                   0
# recent_avg_time_per_activity                434
# days_since_last_activity                    177
# total_time_spent_on_activity_before_exam    177
# average_percentage_past_exams               328
# avg_activities_per_day_recent                 0
# active_days_ratio_recent                      0
# diversity_recent                            434
# dtype: int64

# %%
performances_essay_features.dropna(inplace=True)

# %%
performances_essay_features # only 65 rows left
# Out:
#         user_id domain       test_id  course       date  percentage  \
# 2.0           4  essay   eroerterung    3301 2024-11-21   66.000000
# 5.0           6  essay       bericht    3301 2024-11-05   60.000000
# 54.0         17  essay  beschreibung    5447 2024-11-17   27.058824
# 189.0        81  essay   eroerterung    3301 2024-12-30   69.000000
# 321.0       224  essay  beschreibung    3301 2024-11-08   65.000000
# ...         ...    ...           ...     ...        ...         ...
# 3711.0     3963  essay  beschreibung    5447 2024-12-02   70.588235
# 3713.0     3964  essay       bericht    5447 2024-11-30   77.647059
# 3769.0     3977  essay       bericht    5447 2024-12-04   71.764706
# 3824.0     3999  essay    erzaehlung    3301 2024-12-08   77.000000
# 3858.0     4030  essay       bericht    5447 2025-01-06   68.235294
#
#         performance  recent_avg_time_per_activity  days_since_last_activity  \
# 2.0       -4.090000                     11.233333                      10.0
# 5.0      -11.480000                     59.479167                      10.0
# 54.0     -43.721176                      2.166667                       5.0
# 189.0     -1.090000                      3.756667                       0.0
# 321.0     -4.960000                      7.938889                       7.0
# ...             ...                           ...                       ...
# 3711.0    -0.191765                     20.033333                       7.0
# 3713.0    10.487059                     19.566667                       8.0
# 3769.0     4.604706                      3.711111                       8.0
# 3824.0     9.390000                      3.753333                       8.0
# 3858.0     1.075294                      5.950000                       9.0
#
#         total_time_spent_on_activity_before_exam  \
# 2.0                                    22.466667
# 5.0                                   475.833333
# 54.0                                    2.166667
# 189.0                                 212.300000
# 321.0                                  23.816667
# ...                                          ...
# 3711.0                                 20.033333
# 3713.0                                173.133333
# 3769.0                                 32.233333
# 3824.0                                 22.866667
# 3858.0                                 86.316667
#
#         average_percentage_past_exams  avg_activities_per_day_recent  \
# 2.0                         71.000000                            0.2
# 5.0                         52.000000                            0.8
# 54.0                        30.588235                            0.1
# 189.0                       62.000000                            0.5
# 321.0                       57.000000                            0.3
# ...                               ...                            ...
# 3711.0                      60.000000                            0.1
# 3713.0                      67.058824                            0.1
# 3769.0                      92.941176                            0.3
# 3824.0                      83.000000                            0.5
# 3858.0                      87.058824                            0.8
#
#         active_days_ratio_recent  diversity_recent
# 2.0                          0.1               1.0
# 5.0                          0.1               3.0
# 54.0                         0.1               1.0
# 189.0                        0.1               1.0
# 321.0                        0.1               2.0
# ...                          ...               ...
# 3711.0                       0.1               1.0
# 3713.0                       0.1               1.0
# 3769.0                       0.1               1.0
# 3824.0                       0.1               1.0
# 3858.0                       0.2               2.0
#
# [65 rows x 14 columns]

# %%
# scale the df

columns_to_scale = ['recent_avg_time_per_activity', 'days_since_last_activity', 'total_time_spent_on_activity_before_exam','average_percentage_past_exams','avg_activities_per_day_recent','diversity_recent']


scaler = StandardScaler()
scaled_values = scaler.fit_transform(performances_essay_features[columns_to_scale])
scaled_df = pd.DataFrame(scaled_values, columns=columns_to_scale, index=performances_essay_features.index)

remaining_df = performances_essay_features.drop(columns=columns_to_scale)

final_df = pd.concat([scaled_df, remaining_df], axis=1)

# %%
# Linear Regression Model
mod = smf.ols(formula='performance ~  recent_avg_time_per_activity + days_since_last_activity + total_time_spent_on_activity_before_exam + average_percentage_past_exams + avg_activities_per_day_recent + diversity_recent', data=final_df)

# Fit the model
res = mod.fit()

# Print regression results summary
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            performance   R-squared:                       0.349
# Model:                            OLS   Adj. R-squared:                  0.282
# Method:                 Least Squares   F-statistic:                     5.190
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):           0.000248
# Time:                        09:57:09   Log-Likelihood:                -249.48
# No. Observations:                  65   AIC:                             513.0
# Df Residuals:                      58   BIC:                             528.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    2.8561      1.476      1.936      0.058      -0.097       5.810
# recent_avg_time_per_activity                 6.9390      2.353      2.949      0.005       2.229      11.649
# days_since_last_activity                    -0.3344      1.495     -0.224      0.824      -3.327       2.658
# total_time_spent_on_activity_before_exam    -0.4640      2.169     -0.214      0.831      -4.805       3.877
# average_percentage_past_exams                6.1375      1.490      4.118      0.000       3.154       9.121
# avg_activities_per_day_recent                5.9390      2.569      2.312      0.024       0.796      11.081
# diversity_recent                            -7.0026      2.506     -2.795      0.007     -12.018      -1.987
# ==============================================================================
# Omnibus:                       19.098   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.924
# Skew:                          -1.276   Prob(JB):                     6.38e-06
# Kurtosis:                       4.522   Cond. No.                         3.69
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Let's try with the text results now

# %%
performances_text = performances[performances['domain']== 'text'].copy()
activity_text= activity[activity['domain']== 'text'].copy()

# %%
activity_text.isnull().sum() # issue with the activity completed comlumn, way too many nans. Idk how we should handle those.
# Out:
# activity_id              0
# user_id                  0
# post_id                  0
# course_id                0
# activity_type            0
# activity_status          0
# activity_started         0
# activity_completed    7666
# activity_updated         0
# domain                   0
# date_restored            0
# times_valid              0
# date                     0
# time_spent               0
# time_in_minutes          0
# time_truncated           0
# dtype: int64

# %%
activity_text
# Out:
#        activity_id  user_id  post_id  course_id activity_type  \
# 18            1207     2533     2115       2115        access
# 19            1208     2533     2115       2115        course
# 20            1209     2533     2150       2115        lesson
# 21            1210     2533     2117       2115         topic
# 22            1211     2533     2152       2115         topic
# ...            ...      ...      ...        ...           ...
# 52739          627     2516  2000627       2115          exam
# 52740          628     1629  2000628       5009          exam
# 52741          629     2185  2000629       2115          exam
# 52742          630     2516  2000630       5009          exam
# 52743          631     1859  2000631       5009          exam
#
#        activity_status     activity_started   activity_completed  \
# 18                   0  2023-05-02 08:49:46  2023-05-02 08:49:46
# 19                   0  2023-05-02 08:50:00  2023-05-02 08:50:16
# 20                   0  2023-05-02 08:50:00                  NaN
# 21                   1  2023-05-02 08:50:00  2023-05-02 08:50:16
# 22                   0  2023-05-02 08:50:16                  NaN
# ...                ...                  ...                  ...
# 52739                1  2025-01-04 13:42:05  2025-01-04 13:42:05
# 52740                1  2024-08-26 17:44:36  2024-08-26 18:25:07
# 52741                1  2024-10-30 14:02:31  2024-10-30 14:02:34
# 52742                1  2025-01-04 13:08:50  2025-01-04 13:11:53
# 52743                1  2025-01-05 17:52:30  2025-01-05 18:26:35
#
#           activity_updated domain  date_restored  times_valid        date  \
# 18     2023-05-02 08:49:46   text           True         True  2023-05-02
# 19     2023-05-02 08:50:16   text           True         True  2023-05-02
# 20     2023-05-02 08:50:00   text          False         True  2023-05-02
# 21     2023-05-02 08:50:16   text          False         True  2023-05-02
# 22     2023-05-02 08:50:16   text          False         True  2023-05-02
# ...                    ...    ...            ...          ...         ...
# 52739  2025-01-04 13:42:05   text          False         True  2025-01-04
# 52740  2024-08-26 18:25:07   text          False         True  2024-08-26
# 52741  2024-10-30 14:02:34   text          False         True  2024-10-30
# 52742  2025-01-04 13:11:53   text          False         True  2025-01-04
# 52743  2025-01-05 18:26:35   text          False         True  2025-01-05
#
#             time_spent  time_in_minutes  time_truncated
# 18     0 days 00:00:00         0.000000           False
# 19     0 days 00:00:16         0.266667           False
# 20     0 days 00:00:00         0.000000           False
# 21     0 days 00:00:16         0.266667           False
# 22     0 days 00:00:00         0.000000           False
# ...                ...              ...             ...
# 52739  0 days 00:00:00         0.000000           False
# 52740  0 days 00:40:31        40.516667           False
# 52741  0 days 00:00:03         0.050000           False
# 52742  0 days 00:03:03         3.050000           False
# 52743  0 days 00:34:05        34.083333           False
#
# [13110 rows x 16 columns]

# %%
activity_text.dropna(inplace=True)

# %%
# Convert the date columns to datetime
activity_text['date'] = pd.to_datetime(activity_text['date'])
performances_text['date'] = pd.to_datetime(performances_text['date'])

# Loop over each exam (grouped by user) in performances_text and compute all features.
features_list = []

for user_id, user_exams in performances_text.groupby('user_id'):
    # Get corresponding activities for the user from activity_text and sort by date
    user_activities = activity_text[activity_text['user_id'] == user_id].sort_values('date')
    user_exams_sorted = user_exams.sort_values('date')

    for exam_index, exam_row in user_exams_sorted.iterrows():
        feats = compute_all_features_for_exam(exam_row, user_activities, user_exams_sorted, rolling_window_days)
        feats['exam_index'] = exam_index
        features_list.append(feats)

# Output df
features_df = pd.DataFrame(features_list).set_index('exam_index')
performances_text_features = performances_text.join(features_df, how='left')

# %%
performances_text_features
# Out:
#         user_id domain test_id  course       date  percentage  performance  \
# 192.0        81   text       1    2115 2025-01-04    0.000000     0.000000
# 193.0        81   text      10    5009 2025-01-04    0.000000   -48.710000
# 205.0        90   text       1    2115 2024-12-15    0.000000     0.000000
# 206.0        90   text       3    2115 2024-12-17   76.086957    29.136957
# 207.0        90   text       4    2115 2024-12-15   62.000000    18.720000
# ...         ...    ...     ...     ...        ...         ...          ...
# 4831.0     4095   text       1    2115 2024-08-21    0.000000     0.000000
# 4832.0     4095   text      10    5009 2024-08-21   32.727273   -15.982727
# 4833.0     4095   text      13    5009 2024-10-29   40.298507   -12.121493
# 4834.0     4095   text      14    5009 2024-11-25   52.702703    -6.777297
# 4835.0     4095   text      15    5009 2024-12-09   66.233766     5.243766
#
#         recent_avg_time_per_activity  days_since_last_activity  \
# 192.0                            NaN                      11.0
# 193.0                            NaN                      11.0
# 205.0                      14.372222                       0.0
# 206.0                       9.577778                       0.0
# 207.0                      14.372222                       0.0
# ...                              ...                       ...
# 4831.0                           NaN                       NaN
# 4832.0                           NaN                       NaN
# 4833.0                           NaN                       NaN
# 4834.0                           NaN                       NaN
# 4835.0                           NaN                       NaN
#
#         total_time_spent_on_activity_before_exam  \
# 192.0                                   6.100000
# 193.0                                   6.100000
# 205.0                                  43.116667
# 206.0                                  57.466667
# 207.0                                  43.116667
# ...                                          ...
# 4831.0                                       NaN
# 4832.0                                       NaN
# 4833.0                                       NaN
# 4834.0                                       NaN
# 4835.0                                       NaN
#
#         average_percentage_past_exams  avg_activities_per_day_recent  \
# 192.0                             NaN                            0.0
# 193.0                             NaN                            0.0
# 205.0                             NaN                            0.3
# 206.0                       31.000000                            0.6
# 207.0                             NaN                            0.3
# ...                               ...                            ...
# 4831.0                            NaN                            0.0
# 4832.0                            NaN                            0.0
# 4833.0                      16.363636                            0.0
# 4834.0                      24.341927                            0.0
# 4835.0                      31.432121                            0.0
#
#         active_days_ratio_recent  diversity_recent
# 192.0                        0.0               NaN
# 193.0                        0.0               NaN
# 205.0                        0.2               2.0
# 206.0                        0.3               2.0
# 207.0                        0.2               2.0
# ...                          ...               ...
# 4831.0                       0.0               NaN
# 4832.0                       0.0               NaN
# 4833.0                       0.0               NaN
# 4834.0                       0.0               NaN
# 4835.0                       0.0               NaN
#
# [445 rows x 14 columns]

# %%
performances_text_features.isnull().sum() # too many nans
# Out:
# user_id                                       0
# domain                                        0
# test_id                                       0
# course                                        0
# date                                          0
# percentage                                    0
# performance                                   0
# recent_avg_time_per_activity                363
# days_since_last_activity                    304
# total_time_spent_on_activity_before_exam    304
# average_percentage_past_exams               219
# avg_activities_per_day_recent                 0
# active_days_ratio_recent                      0
# diversity_recent                            363
# dtype: int64

# %%
performances_text_features.dropna(inplace=True)

# %%
performances_text_features
# Out:
#         user_id domain test_id  course       date  percentage  performance  \
# 206.0        90   text       3    2115 2024-12-17   76.086957    29.136957
# 208.0        90   text       5    2115 2024-12-21   59.615385     2.835385
# 209.0        90   text       6    2115 2024-12-23   61.224490    13.434490
# 210.0        90   text       7    2115 2024-12-28   59.090909    -3.179091
# 211.0        90   text       8    2115 2024-12-29   51.515152     6.445152
# 567.0       265   text       6    2115 2024-11-21   30.000000   -17.790000
# 601.0       269   text       6    2115 2024-11-23   36.956522   -10.833478
# 1702.0      489   text       8    2115 2025-01-05   42.105263    -2.964737
# 1719.0      490   text       4    2115 2024-11-27   34.000000    -9.280000
# 1722.0      490   text       7    2115 2024-12-10   62.000000    -0.270000
# 1723.0      490   text       8    2115 2025-01-03   62.500000    17.430000
# 1748.0      491   text       4    2115 2024-11-27   26.000000   -17.280000
# 1750.0      491   text       6    2115 2024-11-24   47.826087     0.036087
# 1751.0      491   text       7    2115 2024-12-10   74.000000    11.730000
# 1795.0      502   text       4    2115 2024-11-27   20.000000   -23.280000
# 2213.0     3241   text      11    5009 2024-10-11   60.000000     5.010000
# 2520.0     3745   text      15    5009 2024-12-08   75.324675    14.334675
# 2611.0     3778   text       1    2115 2025-01-04    0.000000     0.000000
# 2613.0     3778   text      11    5009 2025-01-04   67.605634    12.615634
# 3078.0     3860   text       5    2115 2024-12-18   47.368421    -9.411579
# 3885.0     4030   text       8    2115 2024-12-27   75.000000    29.930000
# 3886.0     4030   text       9    2115 2024-12-27   55.319149    11.099149
# 4332.0     4061   text       1    2115 2024-10-16    0.000000     0.000000
# 4334.0     4061   text      11    5009 2024-10-16   73.239437    18.249437
# 4336.0     4061   text      14    5009 2024-11-05   74.324324    14.844324
#
#         recent_avg_time_per_activity  days_since_last_activity  \
# 206.0                       9.577778                       0.0
# 208.0                       8.629630                       0.0
# 209.0                       8.629630                       2.0
# 210.0                       6.733333                       7.0
# 211.0                       6.733333                       8.0
# 567.0                       0.200000                       2.0
# 601.0                       0.783333                       6.0
# 1702.0                      0.194737                       0.0
# 1719.0                      7.605556                       0.0
# 1722.0                     24.422222                       0.0
# 1723.0                     19.800000                       0.0
# 1748.0                      7.150000                       4.0
# 1750.0                      7.150000                       1.0
# 1751.0                      4.962500                       2.0
# 1795.0                      5.558333                       0.0
# 2213.0                      9.254762                       0.0
# 2520.0                      1.316667                       0.0
# 2611.0                     15.116667                       5.0
# 2613.0                     15.116667                       5.0
# 3078.0                      9.161905                       0.0
# 3885.0                      0.854762                       0.0
# 3886.0                      0.854762                       0.0
# 4332.0                      2.750000                       9.0
# 4334.0                      2.750000                       9.0
# 4336.0                      5.725000                       3.0
#
#         total_time_spent_on_activity_before_exam  \
# 206.0                                  57.466667
# 208.0                                  77.666667
# 209.0                                  77.666667
# 210.0                                  77.666667
# 211.0                                  77.666667
# 567.0                                   0.200000
# 601.0                                   0.783333
# 1702.0                                  3.700000
# 1719.0                                 73.050000
# 1722.0                                146.316667
# 1723.0                                205.716667
# 1748.0                                 54.233333
# 1750.0                                 54.233333
# 1751.0                                 74.083333
# 1795.0                                 11.116667
# 2213.0                                182.850000
# 2520.0                                203.550000
# 2611.0                                190.483333
# 2613.0                                190.483333
# 3078.0                                257.550000
# 3885.0                                 15.266667
# 3886.0                                 15.266667
# 4332.0                                  2.750000
# 4334.0                                  2.750000
# 4336.0                                 14.200000
#
#         average_percentage_past_exams  avg_activities_per_day_recent  \
# 206.0                       31.000000                            0.6
# 208.0                       46.028986                            0.9
# 209.0                       49.425585                            0.9
# 210.0                       51.785366                            0.3
# 211.0                       53.002957                            0.3
# 567.0                       14.583333                            0.1
# 601.0                       25.961538                            0.1
# 1702.0                      39.620915                            1.9
# 1719.0                      30.641026                            0.3
# 1722.0                      31.480769                            0.3
# 1723.0                      37.584615                            0.3
# 1748.0                      33.225980                            0.5
# 1750.0                      25.925926                            0.5
# 1751.0                      31.419485                            0.4
# 1795.0                      20.000000                            0.2
# 2213.0                      32.857143                            1.4
# 2520.0                      40.654032                            0.4
# 2611.0                      70.833333                            0.2
# 2613.0                      70.833333                            0.2
# 3078.0                      30.000000                            0.7
# 3885.0                      26.923077                            0.7
# 3886.0                      26.923077                            0.7
# 4332.0                      44.444444                            0.1
# 4334.0                      44.444444                            0.1
# 4336.0                      46.767909                            0.2
#
#         active_days_ratio_recent  diversity_recent
# 206.0                        0.3               2.0
# 208.0                        0.4               2.0
# 209.0                        0.4               2.0
# 210.0                        0.1               1.0
# 211.0                        0.1               1.0
# 567.0                        0.1               1.0
# 601.0                        0.1               1.0
# 1702.0                       0.1               2.0
# 1719.0                       0.2               1.0
# 1722.0                       0.2               1.0
# 1723.0                       0.2               1.0
# 1748.0                       0.1               1.0
# 1750.0                       0.1               1.0
# 1751.0                       0.1               1.0
# 1795.0                       0.1               1.0
# 2213.0                       0.3               2.0
# 2520.0                       0.1               1.0
# 2611.0                       0.2               1.0
# 2613.0                       0.2               1.0
# 3078.0                       0.2               1.0
# 3885.0                       0.2               1.0
# 3886.0                       0.2               1.0
# 4332.0                       0.1               1.0
# 4334.0                       0.1               1.0
# 4336.0                       0.1               1.0

# %%
# Scale the columns
columns_to_scale = ['recent_avg_time_per_activity', 'days_since_last_activity', 'total_time_spent_on_activity_before_exam','average_percentage_past_exams','avg_activities_per_day_recent','diversity_recent']

scaler = StandardScaler()
scaled_values = scaler.fit_transform(performances_text_features[columns_to_scale])
scaled_df = pd.DataFrame(scaled_values, columns=columns_to_scale, index=performances_text_features.index)

remaining_df = performances_text_features.drop(columns=columns_to_scale)

final_df = pd.concat([scaled_df, remaining_df], axis=1)

# %%
final_df # only 25 rows left, not really relevant
# Out:
#         recent_avg_time_per_activity  days_since_last_activity  \
# 206.0                       0.388782                 -0.812920
# 208.0                       0.231016                 -0.812920
# 209.0                       0.231016                 -0.167745
# 210.0                      -0.084516                  1.445191
# 211.0                      -0.084516                  1.767779
# 567.0                      -1.171622                 -0.167745
# 601.0                      -1.074559                  1.122604
# 1702.0                     -1.172498                 -0.812920
# 1719.0                      0.060616                 -0.812920
# 1722.0                      2.858805                 -0.812920
# 1723.0                      2.089696                 -0.812920
# 1748.0                     -0.015186                  0.477429
# 1750.0                     -0.015186                 -0.490333
# 1751.0                     -0.379172                 -0.167745
# 1795.0                     -0.280029                 -0.812920
# 2213.0                      0.335034                 -0.812920
# 2520.0                     -0.985816                 -0.812920
# 2611.0                      1.310418                  0.800017
# 2613.0                      1.310418                  0.800017
# 3078.0                      0.319583                 -0.812920
# 3885.0                     -1.062674                 -0.812920
# 3886.0                     -1.062674                 -0.812920
# 4332.0                     -0.747318                  2.090366
# 4334.0                     -0.747318                  2.090366
# 4336.0                     -0.252297                  0.154842
#
#         total_time_spent_on_activity_before_exam  \
# 206.0                                  -0.323634
# 208.0                                  -0.064234
# 209.0                                  -0.064234
# 210.0                                  -0.064234
# 211.0                                  -0.064234
# 567.0                                  -1.059031
# 601.0                                  -1.051540
# 1702.0                                 -1.014085
# 1719.0                                 -0.123519
# 1722.0                                  0.817343
# 1723.0                                  1.580135
# 1748.0                                 -0.365156
# 1750.0                                 -0.365156
# 1751.0                                 -0.110250
# 1795.0                                 -0.918843
# 2213.0                                  1.286490
# 2520.0                                  1.552311
# 2611.0                                  1.384514
# 2613.0                                  1.384514
# 3078.0                                  2.245758
# 3885.0                                 -0.865550
# 3886.0                                 -0.865550
# 4332.0                                 -1.026285
# 4334.0                                 -1.026285
# 4336.0                                 -0.879248
#
#         average_percentage_past_exams  avg_activities_per_day_recent  \
# 206.0                       -0.532226                       0.256319
# 208.0                        0.570346                       0.968316
# 209.0                        0.819531                       0.968316
# 210.0                        0.992652                      -0.455678
# 211.0                        1.081978                      -0.455678
# 567.0                       -1.736604                      -0.930342
# 601.0                       -0.901863                      -0.930342
# 1702.0                       0.100230                       3.341638
# 1719.0                      -0.558562                      -0.455678
# 1722.0                      -0.496956                      -0.455678
# 1723.0                      -0.049159                      -0.455678
# 1748.0                      -0.368922                       0.018987
# 1750.0                      -0.904476                       0.018987
# 1751.0                      -0.501452                      -0.218346
# 1795.0                      -1.339220                      -0.693010
# 2213.0                      -0.395981                       2.154977
# 2520.0                       0.176023                      -0.218346
# 2611.0                       2.390069                      -0.693010
# 2613.0                       2.390069                      -0.693010
# 3078.0                      -0.605589                       0.493651
# 3885.0                      -0.831322                       0.493651
# 3886.0                      -0.831322                       0.493651
# 4332.0                       0.454099                      -0.930342
# 4334.0                       0.454099                      -0.930342
# 4336.0                       0.624556                      -0.693010
#
#         diversity_recent  user_id domain test_id  course       date  \
# 206.0                2.0       90   text       3    2115 2024-12-17
# 208.0                2.0       90   text       5    2115 2024-12-21
# 209.0                2.0       90   text       6    2115 2024-12-23
# 210.0               -0.5       90   text       7    2115 2024-12-28
# 211.0               -0.5       90   text       8    2115 2024-12-29
# 567.0               -0.5      265   text       6    2115 2024-11-21
# 601.0               -0.5      269   text       6    2115 2024-11-23
# 1702.0               2.0      489   text       8    2115 2025-01-05
# 1719.0              -0.5      490   text       4    2115 2024-11-27
# 1722.0              -0.5      490   text       7    2115 2024-12-10
# 1723.0              -0.5      490   text       8    2115 2025-01-03
# 1748.0              -0.5      491   text       4    2115 2024-11-27
# 1750.0              -0.5      491   text       6    2115 2024-11-24
# 1751.0              -0.5      491   text       7    2115 2024-12-10
# 1795.0              -0.5      502   text       4    2115 2024-11-27
# 2213.0               2.0     3241   text      11    5009 2024-10-11
# 2520.0              -0.5     3745   text      15    5009 2024-12-08
# 2611.0              -0.5     3778   text       1    2115 2025-01-04
# 2613.0              -0.5     3778   text      11    5009 2025-01-04
# 3078.0              -0.5     3860   text       5    2115 2024-12-18
# 3885.0              -0.5     4030   text       8    2115 2024-12-27
# 3886.0              -0.5     4030   text       9    2115 2024-12-27
# 4332.0              -0.5     4061   text       1    2115 2024-10-16
# 4334.0              -0.5     4061   text      11    5009 2024-10-16
# 4336.0              -0.5     4061   text      14    5009 2024-11-05
#
#         percentage  performance  active_days_ratio_recent
# 206.0    76.086957    29.136957                       0.3
# 208.0    59.615385     2.835385                       0.4
# 209.0    61.224490    13.434490                       0.4
# 210.0    59.090909    -3.179091                       0.1
# 211.0    51.515152     6.445152                       0.1
# 567.0    30.000000   -17.790000                       0.1
# 601.0    36.956522   -10.833478                       0.1
# 1702.0   42.105263    -2.964737                       0.1
# 1719.0   34.000000    -9.280000                       0.2
# 1722.0   62.000000    -0.270000                       0.2
# 1723.0   62.500000    17.430000                       0.2
# 1748.0   26.000000   -17.280000                       0.1
# 1750.0   47.826087     0.036087                       0.1
# 1751.0   74.000000    11.730000                       0.1
# 1795.0   20.000000   -23.280000                       0.1
# 2213.0   60.000000     5.010000                       0.3
# 2520.0   75.324675    14.334675                       0.1
# 2611.0    0.000000     0.000000                       0.2
# 2613.0   67.605634    12.615634                       0.2
# 3078.0   47.368421    -9.411579                       0.2
# 3885.0   75.000000    29.930000                       0.2
# 3886.0   55.319149    11.099149                       0.2
# 4332.0    0.000000     0.000000                       0.1
# 4334.0   73.239437    18.249437                       0.1
# 4336.0   74.324324    14.844324                       0.1

# %%
# Linear Regression Model
mod = smf.ols(formula='performance ~  recent_avg_time_per_activity + days_since_last_activity + total_time_spent_on_activity_before_exam + average_percentage_past_exams + avg_activities_per_day_recent + diversity_recent', data=final_df)

# Fit the model
res = mod.fit()

# Print regression results summary
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            performance   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                 -0.100
# Method:                 Least Squares   F-statistic:                    0.6372
# Date:                Thu, 17 Apr 2025   Prob (F-statistic):              0.699
# Time:                        10:11:37   Log-Likelihood:                -98.268
# No. Observations:                  25   AIC:                             210.5
# Df Residuals:                      18   BIC:                             219.1
# Df Model:                           6
# Covariance Type:            nonrobust
# ============================================================================================================
#                                                coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------
# Intercept                                    3.7137      2.906      1.278      0.217      -2.391       9.818
# recent_avg_time_per_activity                -1.9420      4.275     -0.454      0.655     -10.923       7.039
# days_since_last_activity                    -5.3063      5.037     -1.054      0.306     -15.888       5.276
# total_time_spent_on_activity_before_exam    -0.9326      4.468     -0.209      0.837     -10.319       8.454
# average_percentage_past_exams                7.1002      4.653      1.526      0.144      -2.676      16.876
# avg_activities_per_day_recent               -3.3370      5.412     -0.617      0.545     -14.708       8.034
# diversity_recent                             3.2268      4.920      0.656      0.520      -7.110      13.564
# ==============================================================================
# Omnibus:                        0.534   Durbin-Watson:                   2.122
# Prob(Omnibus):                  0.766   Jarque-Bera (JB):                0.549
# Skew:                           0.302   Prob(JB):                        0.760
# Kurtosis:                       2.598   Cond. No.                         3.74
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
